# %%
import pandas as pd
import sqlite3

# %%
conexao = sqlite3.connect('Netflix.db')
consulta_sql = "SELECT * FROM Data"
df = pd.read_sql_query(consulta_sql, conexao)
conexao.close()

df
# Out:
#       false show_id     type                  title         director  \
# 0         0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         1      s2  TV Show          Blood & Water             None
# 2         2      s3  TV Show              Ganglands  Julien Leclercq
# 3         3      s4  TV Show  Jailbirds New Orleans             None
# 4         4      s5  TV Show           Kota Factory             None
# ...     ...     ...      ...                    ...              ...
# 8802   8802   s8803    Movie                 Zodiac    David Fincher
# 8803   8803   s8804  TV Show            Zombie Dumb             None
# 8804   8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
print(df['director'].isnull().sum())
# Out:
# 2634

# %%
import random
for director,line in df.iterrows():
    if pd.isnull(line['director']):
        samples = df[df['country'] == line['country']]
        samples = samples.dropna(subset=['director'])
        if not samples.empty:
            diretor = samples.sample()['director']
            df.at[director,'director'] = diretor.values[0]

# %%
import random
for director,line in df.iterrows():
    if pd.isnull(line['director']):
        samples = df[df['cast'] == line['cast']]
        samples = samples.dropna(subset=['director'])
        if not samples.empty:
            diretor = samples.sample()['director']
            df.at[director,'director'] = diretor.values[0]

# %%
print(df['director'].isnull().sum())
# Out:
# 483

# %%
print(df['country'].isnull().sum())
# Out:
# 831

# %%
for country,line in df.iterrows():
    if pd.isnull(line['country']):
        samples = df[df['director'] == line['director']]
        samples = samples.dropna(subset=['country'])
        if not samples.empty:
            pais = samples.sample()['country']
            df.at[country,'country'] = pais.values[0]

# %%
print(df['country'].isnull().sum())
# Out:
# 662

# %%
print(df['cast'].isnull().sum())
# Out:
# 825

# %%
for index, row in df.iterrows():
    if pd.isnull(row['cast']):
        director = row['director']
        samples = df[(df['director'] == director) & ~df['cast'].isnull()]
        if not samples.empty:
            cast_value = samples.sample()['cast'].values[0]
            df.at[index, 'cast'] = cast_value

# %%
print(df['cast'].isnull().sum())
# Out:
# 415

# %%
for director,line in df.iterrows():
    if pd.isnull(line['director']):
         df.at[director,'director'] = 'Not Given'
for country,line in df.iterrows():
    if pd.isnull(line['country']):
         df.at[country,'country'] = 'Not Given'
for cast,line in df.iterrows():
    if pd.isnull(line['cast']):
         df.at[country,'cast'] = 'Not Given'

# %%
df = df.dropna()
df
# Out:
#       false show_id     type                 title                   director  \
# 0         0      s1    Movie  Dick Johnson Is Dead            Kirsten Johnson
# 1         1      s2  TV Show         Blood & Water  Pippa Ehrlich, James Reed
# 2         2      s3  TV Show             Ganglands            Julien Leclercq
# 4         4      s5  TV Show          Kota Factory    Rakeysh Omprakash Mehra
# 5         5      s6  TV Show         Midnight Mass              Mike Flanagan
# ...     ...     ...      ...                   ...                        ...
# 8801   8801   s8802    Movie               Zinzana            Majid Al Ansari
# 8802   8802   s8803    Movie                Zodiac              David Fincher
# 8804   8804   s8805    Movie            Zombieland            Ruben Fleischer
# 8805   8805   s8806    Movie                  Zoom               Peter Hewitt
# 8806   8806   s8807    Movie                Zubaan                Mozez Singh
#
# ...
